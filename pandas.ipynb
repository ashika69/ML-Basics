# %% [markdown]
# <a href="https://colab.research.google.com/github/ashika69/ML-Basics/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
my_list = [10,20,30]
arr = np.array(my_list)
arr
# Out:
# array([10, 20, 30])

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
lables = ['a','b','c']
pd.Series(data=my_list , index = lables )
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series(data = [10,20,30],index = ['ashi','abhi','rama'])
ser2 = pd.Series(data = [10,20,60],index = ['ashi','abhi','rk'])

# %%
ser1
# Out:
# ashi    10
# abhi    20
# rama    30
# dtype: int64

# %%
ser1+ser2
# Out:
# abhi    40.0
# ashi    20.0
# rama     NaN
# rk       NaN
# dtype: float64

# %%
df1 = pd.DataFrame({'A' : ['a1','a2','a3'],     #dataframe  arranges a group of series in table form (mostly dict items)
        'B' : ['b1','b2','b3'],
        'c' : ['c1','c2','c3']},index = [1,2,3])
df2 = pd.DataFrame({'A' : ['a4','a5','a6'],
        'B' : ['b4','b5','b6'],
        'c' : ['c4','c5','c6']},index = [4,5,6])

# %%
pd.concat([df1,df2])
# Out:
#     A   B   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5
# 6  a6  b6  c6
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_0, *['A'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
# ...
